# %%
from logging_module.logger import get_logger
logger=get_logger(name="test_kafka")

# %%
logger.info("testing")
# Out:
# 2026-01-15 15:52:32,735 - test_kafka - INFO - testing

# %%
from confluent_kafka import Producer
import socket

conf = {'bootstrap.servers': 'localhost:9092',
        'client.id': socket.gethostname()}

producer = Producer(conf)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for i in producer:
#       2     print(i)
#
# TypeError: 'cimpl.Producer' object is not iterable
